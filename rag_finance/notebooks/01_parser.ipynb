# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from pathlib import Path

from src.parser import EnterprisePDFParser

# %%
pdf = EnterprisePDFParser(

    "../data/raw/3m_2018.pdf"

)

# %%
text_blocks = pdf.extract_text()

table_blocks = pdf.extract_tables()

# %%
len(text_blocks)
# Out:
# 160

# %%
len(table_blocks)
# Out:
# 160

# %%
table_blocks[45]
# Out:
# {'page': 46,
#  'tables': [{'page': 46,
#    'table': [['Net income including noncontrolling interest',
#      '',
#      '$',
#      '5,363',
#      '',
#      '$',
#      '4,869',
#      '',
#      '$',
#      '5,058']]},
#   {'page': 46,
#    'table': [['Company pension and postretirement contributions',
#      '',
#      '',
#      '(370)',
#      '',
#      '',
#      '(967)',
#      '',
#      '',
#      '(383)']]},
#   {'page': 46,
#    'table': [['Stock-based compensation expense',
#      '',
#      '',
#      '302',
#      '',
#      '',
#      '324',
#      '',
#      '',
#      '298']]},
#   {'page': 46,
#    'table': [['Income taxes (deferred and accrued income taxes)',
#      '',
#      '',
#      '77',
#      '',
#      '',
#      '1,074',
#      '',
#      '',
#      '108']]},
#   {'page': 46,
#    'table': [['Inventories', '', '', '(509)', '', '', '(387)', '', '', '57']]},
#   {'page': 46,
#    'table': [['Other — net', '', '', '120', '', '', '256', '', '', '76']]},
# ...

# %%
count = 0

for page in table_pages:

    if page["tables"]:
        count += 1

print(count)
# Out:
# 77

# %%
for page in table_pages:

    if page["tables"]:

        print("Page:", page["page"])

        display(page["tables"][0])

        break
# Out:
# Page: 8
#                      Name       Age       \
# 0         Inge. G. Thulin        65
# 1                          NaN  NaN  NaN
# 2        Michael F. Roman        59
# 3                          NaN  NaN  NaN
# 4        John P. Banovetz        51
# 5                          NaN  NaN  NaN
# 6         James L. Bauman        59
# 7                          NaN  NaN  NaN
# 8        Julie L. Bushman        57
# 9                          NaN  NaN  NaN
# 10        Joaquin Delgado        58
# 11                         NaN  NaN  NaN
# 12           Ivan K. Fong        57
# 13                         NaN  NaN  NaN
# 14  Nicholas C. Gangestad        54
# 15                         NaN  NaN  NaN
# 16         Eric D. Hammes        44
# 17                         NaN  NaN  NaN
# 18           Paul A. Keel        49
# 19                         NaN  NaN  NaN
# 20     Ashish K. Khandpur        51
# 21                         NaN  NaN  NaN
#
# ...

# %%
import pdfplumber

pdf = pdfplumber.open("../data/raw/3m_2018.pdf")

page = pdf.pages[45]

page.find_tables()

# %%
len(page.find_tables())
# Out:
# 9
